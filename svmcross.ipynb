# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay47847/pcg_classification/blob/main/svmcross.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
from scipy.io import wavfile
from scipy.signal import stft
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler

# Function to load audio files from a specified folder
def load_audio_files(file_list, folder_path):
    audio_data = []
    record_names = []
    min_length = float('inf')
    for file_name in file_list:
        file_path = os.path.join(folder_path, file_name)
        sr, y = wavfile.read(file_path)  # Load the audio file
        audio_data.append(y)
        record_names.append(file_name)
        min_length = min(min_length, len(y))
    # Trim all audio files to the minimum length
    audio_data = [audio[:min_length] for audio in audio_data]
    return np.array(audio_data), record_names, sr

# Function to normalize audio data using z-score
def z_score_normalize_audio_data(audio_data):
    normalized_audio = []
    for signal in audio_data:
        mean_val = np.mean(signal)
        std_val = np.std(signal)
        if std_val == 0:
            normalized_signal = signal - mean_val
        else:
            normalized_signal = (signal - mean_val) / std_val
        normalized_audio.append(normalized_signal)
    return np.array(normalized_audio)

# Function to compute STFT
def compute_stft(audio_data, sample_rate, nperseg, noverlap):
    stft_list = []
    for signal in audio_data:
        f, t, Zxx = stft(signal, fs=sample_rate, nperseg=nperseg, noverlap=noverlap)
        stft_list.append(20 * np.log10(np.abs(Zxx)))
    stft_array = np.array(stft_list)
    return f, t, stft_array

# Function to slice the STFT and retrieve the values
def slice_stft(stft_array, frequencies, start_freq, stop_freq, increment, overlap):
    stft_slices = []
    low = start_freq
    while low < stop_freq:
        high = low + increment
        if high > stop_freq:
            high = stop_freq
        freq_mask = (frequencies >= low) & (frequencies < high)
        sliced_stft = stft_array[:, freq_mask, :]
        stft_slices.append((low, high, sliced_stft))
        low += (increment - overlap)
    return stft_slices

# Load the Excel file and select relevant columns
df = pd.read_excel('/content/PMEA_37_12_2181_OnlineAppendix.xlsx', sheet_name='SUAHSDB')
df = df[['Record name', 'Type (-1=normal 1=abnormal)']]

# Define the folder path containing the audio files
folder_path = '/content/drive/MyDrive/training-f'

# Get a list of all .wav files in the folder
audio_files = [file for file in os.listdir(folder_path) if file.endswith('.wav')]

# Filter the audio files based on record names
audio_files_filtered = [file for file in audio_files if any(record in file for record in df['Record name'])]

# Load audio data
audio_data, record_names_loaded, sample_rate = load_audio_files(audio_files_filtered, folder_path)

# Extract 2.5 seconds of audio
duration = 2.5
num_samples = int(duration * sample_rate)
audio_data = audio_data[:, :num_samples]


# Z-normalize the audio data
audio_data_norm = z_score_normalize_audio_data(audio_data)

# Initialize the scaler for feature standardization
scaler = StandardScaler()

# Apply k-fold cross-validation
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize SVM classifier
svm_classifier = SVC(kernel='linear')

# STFT parameters
nperseg = 200
noverlap = int((50/100)*nperseg)

# Define slicing parameters
start_freq = 0
stop_freq = 1000
#changing parameter
increment_initial = 50
Iterations =20

# Store accuracies nperseg and UR values for plotting
All_Accuracy = []
All_UAR = []
All_increment = []

# Loop through iteration
for iteration in range(Iterations):
    increment =increment_initial + iteration * 50
    overlap = int((30/100)*increment)

    # Compute STFT
    frequencies, times, stft_array = compute_stft(audio_data_norm, sample_rate, nperseg, noverlap)

    # Slice STFT and get values
    stft_slices = slice_stft(stft_array, frequencies, start_freq, stop_freq, increment, overlap)

    # Prepare data for DataFrame
    feature_dict = {'Record Name': record_names_loaded}

    # Add STFT slices to the feature dictionary without averaging
    for low, high, stft_slice in stft_slices:
        for bin_index in range(stft_slice.shape[1]):  # Each frequency bin
            for time_index in range(stft_slice.shape[2]):  # Each time bin
                feature_name = f'STFT {low}-{high} Hz Bin {bin_index + 1} Time {time_index + 1}'
                feature_dict[feature_name] = stft_slice[:, bin_index, time_index]

    # Convert the feature dictionary to a DataFrame
    df_features = pd.DataFrame(feature_dict)

    # Sort DataFrame by 'Record Name' in ascending order and reset index
    df_features_sorted = df_features.sort_values(by='Record Name').reset_index(drop=True)

    # Reassign the 'Type' column to maintain its original order
    df_features_sorted['Type (-1=normal 1=abnormal)'] = df['Type (-1=normal 1=abnormal)'].values

    # Select all STFT features
    selected_columns = [col for col in df_features_sorted.columns if col.startswith('STFT')]

    # Separate features and labels
    X = df_features_sorted[selected_columns].values
    y = df_features_sorted['Type (-1=normal 1=abnormal)'].values

    # Fit the scaler on the data and transform
    standardized_data = scaler.fit_transform(X)

    # Store results for each fold
    conf_matrices = []
    accuracies = []
    sensitivities = []
    specificities = []
    precisions = []
    f1_scores = []

    # Perform k-fold cross-validation manually
    for train_index, test_index in kfold.split(standardized_data, y):
        X_train, X_test = standardized_data[train_index], standardized_data[test_index]
        y_train, y_test = y[train_index], y[test_index]

        svm_classifier.fit(X_train, y_train)
        y_pred = svm_classifier.predict(X_test)

        # Compute confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        conf_matrices.append(conf_matrix)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        sensitivity = recall_score(y_test, y_pred)
        tn, fp, fn, tp = conf_matrix.ravel()
        specificity = tn / (tn + fp)
        precision = precision_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)


        accuracies.append(accuracy)
        sensitivities.append(sensitivity)
        specificities.append(specificity)
        precisions.append(precision)
        f1_scores.append(f1)

    # Calculate and display the mean metrics for the iteration
    mean_accuracy = np.mean(accuracies)
    mean_sensitivity = np.mean(sensitivities)
    mean_specificity = np.mean(specificities)
    mean_precision = np.mean(precisions)
    mean_f1_score = np.mean(f1_scores)
    UAR=(mean_sensitivity+mean_specificity)/2

    print()
    print(f"Iteration {iteration + 1} Results:")
    print(f"increment: {increment}, overlap: {overlap}")
    print(f"nperseg: {nperseg}, noverlap: {noverlap}")
    print()
    print(f"Mean Accuracy Score: {mean_accuracy * 100:.2f}%")
    print(f"Mean Sensitivity (Recall): {mean_sensitivity:.2f}")
    print(f"Mean Specificity: {mean_specificity:.2f}")
    print(f"Mean Precision: {mean_precision:.2f}")
    print(f"Mean F1 Score: {mean_f1_score:.2f}")
    print(f"UAR: {UAR:.2f}")

    # Display the overall confusion matrix for the iteration
    overall_conf_matrix = np.mean(conf_matrices, axis=0)
    print()
    plt.figure(figsize=(10, 7))
    sns.heatmap(overall_conf_matrix, annot=True, fmt='.2g', cmap='Blues', xticklabels=['Normal', 'Abnormal'], yticklabels=['Normal', 'Abnormal'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(f'Overall Confusion Matrix for iteration {iteration + 1}')
    plt.show()

    # Store results for plotting
    All_UAR.append(UAR)
    All_Accuracy.append(mean_accuracy)
    All_increment.append(increment)

# Plot accuracy versus nperseg
print()
plt.figure(figsize=(17,13))
plt.subplot(2, 1, 1)
plt.plot( All_increment, All_Accuracy)
plt.xlabel('increment')
plt.ylabel('Accuracy')
plt.title('Accuracy vs increment')
plt.grid()

# Plot UR versus nperseg
plt.subplot(2, 1, 2)
plt.plot( All_increment, All_UAR)
plt.xlabel('increment')
plt.ylabel('Unweighted Average Recall (UAR)')
plt.title('UAR vs increment')
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# Iteration 1 Results:
# increment: 50, overlap: 15
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 72.81%
# Mean Sensitivity (Recall): 0.47
# Mean Specificity: 0.84
# Mean Precision: 0.55
# Mean F1 Score: 0.50
# UAR: 0.65
# Iteration 2 Results:
# increment: 100, overlap: 30
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 72.81%
# Mean Sensitivity (Recall): 0.47
# Mean Specificity: 0.84
# Mean Precision: 0.55
# Mean F1 Score: 0.50
# UAR: 0.65
# Iteration 3 Results:
# increment: 150, overlap: 45
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.98%
# Mean Sensitivity (Recall): 0.50
# Mean Specificity: 0.81
# Mean Precision: 0.53
# Mean F1 Score: 0.51
# UAR: 0.66
# Iteration 4 Results:
# increment: 200, overlap: 60
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.94%
# Mean Sensitivity (Recall): 0.47
# Mean Specificity: 0.82
# Mean Precision: 0.53
# Mean F1 Score: 0.50
# UAR: 0.65
# Iteration 5 Results:
# increment: 250, overlap: 75
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.94%
# Mean Sensitivity (Recall): 0.47
# Mean Specificity: 0.82
# Mean Precision: 0.53
# Mean F1 Score: 0.50
# UAR: 0.65
# Iteration 6 Results:
# increment: 300, overlap: 90
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.98%
# Mean Sensitivity (Recall): 0.48
# Mean Specificity: 0.82
# Mean Precision: 0.53
# Mean F1 Score: 0.50
# UAR: 0.65
# Iteration 7 Results:
# increment: 350, overlap: 105
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 70.20%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.81
# Mean Precision: 0.50
# Mean F1 Score: 0.47
# UAR: 0.63
# Iteration 8 Results:
# increment: 400, overlap: 120
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.94%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.84
# Mean Precision: 0.53
# Mean F1 Score: 0.48
# UAR: 0.64
# Iteration 9 Results:
# increment: 450, overlap: 135
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 74.62%
# Mean Sensitivity (Recall): 0.50
# Mean Specificity: 0.85
# Mean Precision: 0.58
# Mean F1 Score: 0.54
# UAR: 0.68
# Iteration 10 Results:
# increment: 500, overlap: 150
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.94%
# Mean Sensitivity (Recall): 0.50
# Mean Specificity: 0.81
# Mean Precision: 0.53
# Mean F1 Score: 0.51
# UAR: 0.66
# Iteration 11 Results:
# increment: 550, overlap: 165
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.94%
# Mean Sensitivity (Recall): 0.47
# Mean Specificity: 0.82
# Mean Precision: 0.53
# Mean F1 Score: 0.50
# UAR: 0.65
# Iteration 12 Results:
# increment: 600, overlap: 180
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 72.81%
# Mean Sensitivity (Recall): 0.47
# Mean Specificity: 0.84
# Mean Precision: 0.55
# Mean F1 Score: 0.50
# UAR: 0.65
# Iteration 13 Results:
# increment: 650, overlap: 195
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 73.72%
# Mean Sensitivity (Recall): 0.47
# Mean Specificity: 0.85
# Mean Precision: 0.57
# Mean F1 Score: 0.51
# UAR: 0.66
# Iteration 14 Results:
# increment: 700, overlap: 210
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 72.85%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.85
# Mean Precision: 0.55
# Mean F1 Score: 0.49
# UAR: 0.65
# Iteration 15 Results:
# increment: 750, overlap: 225
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.98%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.84
# Mean Precision: 0.54
# Mean F1 Score: 0.48
# UAR: 0.64
# Iteration 16 Results:
# increment: 800, overlap: 240
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.11%
# Mean Sensitivity (Recall): 0.41
# Mean Specificity: 0.84
# Mean Precision: 0.53
# Mean F1 Score: 0.46
# UAR: 0.63
# Iteration 17 Results:
# increment: 850, overlap: 255
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 72.85%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.85
# Mean Precision: 0.55
# Mean F1 Score: 0.49
# UAR: 0.65
# Iteration 18 Results:
# increment: 900, overlap: 270
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.98%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.84
# Mean Precision: 0.54
# Mean F1 Score: 0.48
# UAR: 0.64
# Iteration 19 Results:
# increment: 950, overlap: 285
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.98%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.84
# Mean Precision: 0.54
# Mean F1 Score: 0.48
# UAR: 0.64
# Iteration 20 Results:
# increment: 1000, overlap: 300
# nperseg: 200, noverlap: 100
#
# Mean Accuracy Score: 71.94%
# Mean Sensitivity (Recall): 0.44
# Mean Specificity: 0.84
# Mean Precision: 0.53
# Mean F1 Score: 0.48
# UAR: 0.64
